# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghashreeGirish11/Handwriting-Recognition-AI/blob/main/Handwriting_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install opencv-python matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("1000202258.jpg")
print("im is true")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# im is true
# (np.float64(-0.5), np.float64(637.5), np.float64(1421.5), np.float64(-0.5))

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\vimal\Desktop\PROJECTSS\ai_handwriting\Handwriting-Recognition-AI
# ['.git', '1000202258.jpg', 'app.py', 'Handwriting_AI_Model.ipynb', 'Handwriting_AI_Pipeline.ipynb', 'Handwriting_Preprocessing.ipynb', 'processed.png', 'README.md', 'requirements.txt', 'static', 'templates', 'TrOCR_AI.ipynb', 'venv']

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith((".jpg", ".jpeg", ".png")):
            print(os.path.join(root, file))
# Out:
# .\1000202258.jpg
# .\processed.png
# .\venv\Lib\site-packages\ipykernel\resources\logo-32x32.png
# .\venv\Lib\site-packages\ipykernel\resources\logo-64x64.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\back.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\back_large.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\filesave.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\filesave_large.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\forward.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\forward_large.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\hand.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\help.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\help_large.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\home.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\home_large.png
# .\venv\Lib\site-packages\matplotlib\mpl-data\images\matplotlib.png
# ...

# %%
import os

print(os.path.exists("1000202258.jpg"))
# Out:
# True
